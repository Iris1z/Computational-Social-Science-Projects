# %% [markdown]
# # [Computational Social Science] Project 4: Unsupervised Learning
#
# **Enter your Name:** Xiaoxue Zhao
#
# *Semester:* Fall 2024

# %% [markdown]
# ## Data Description and Preprocessing
#
# For this project, you will explore data from the [National Health and Nutrition Examination Survey](https://www.kaggle.com/cdc/national-health-and-nutrition-examination-survey?select=questionnaire.csv). NHANES is a unique study that combines survey methodology with in-person medical examinations to create a dataset with demographic information, health indicators, and health outcomes.

# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (3.7.0)
# Requirement already satisfied: absl-py in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (13.9.3)
# Requirement already satisfied: namex in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (3.12.1)
# Requirement already satisfied: optree in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (0.13.1)
# Requirement already satisfied: ml-dtypes in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (0.4.1)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from optree->keras) (4.11.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from rich->keras) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)

# %%
pip install keras tensorflow
# Out:
# Requirement already satisfied: keras in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (3.7.0)
# Requirement already satisfied: tensorflow in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (2.18.0)
# Requirement already satisfied: absl-py in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (13.9.3)
# Requirement already satisfied: namex in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (3.12.1)
# Requirement already satisfied: optree in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (0.13.1)
# Requirement already satisfied: ml-dtypes in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (0.4.1)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from keras) (24.1)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (5.29.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (72.1.0)
# Requirement already satisfied: six>=1.12.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (1.68.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from rich->keras) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/anaconda3/envs/CSS/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# We start by importing the data and doing some preliminary preprocessing for you. We import some libraries that will be helpful as well. 'SEQN' is the ID number for each respondent, and 'HSD010' will be our target outcome. [HSD010](https://wwwn.cdc.gov/Nchs/Nhanes/2013-2014/HSQ_H.htm#HSD010) asks for the respondent's self reported health condition, which can range from "excellent" to "poor."

# %%
# Import libraries
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection import train_test_split
sns.set_style("darkgrid")
from sklearn.model_selection import train_test_split

# %%
# Load nhanes data
nhanes = pd.read_csv('nhanes.csv')
# Get the ID numbers for each observation (seqn)
seqn = nhanes['SEQN']
# Get the target, "self-reported health condition," HSD010
hsd010 = nhanes['HSD010']
# Drop SEQN from the dataframe and then apply the standard scaler
nhanes = nhanes.drop(['SEQN', 'HSD010'], axis = 1)
nhanes_scaled = pd.DataFrame(StandardScaler().fit_transform(nhanes),
                             columns = nhanes.columns)
# Add the ID and target back in
nhanes_scaled['SEQN'] = seqn
nhanes_scaled['HSD010'] = hsd010
nhanes_scaled = nhanes_scaled.set_index('SEQN')
nhanes_scaled.head()
# Out:
#        DR1DRSTZ  DR1EXMER  DRABF    DRDINT   DR1DBIH    DR1DAY   DR1LANG  \
# SEQN
# 73568       0.0  2.034312    0.0  0.324834 -0.393906  1.085853 -0.194202
# 73576       0.0  0.261930    0.0 -3.078499  0.568251  0.634362 -0.194202
# 73579       0.0  0.728346    0.0  0.324834  1.530407 -1.623092 -0.194202
# 73581       0.0 -0.857470    0.0  0.324834  0.480782  1.085853 -0.194202
# 73584       0.0  0.495138    0.0  0.324834  0.305844 -1.623092 -0.194202
#
#        DR1MNRSP  DR1HELPD   DBQ095Z  ...    OHQ770    OHQ845   PAAQUEX  \
# SEQN                                 ...
# 73568 -0.057306  0.128246 -0.189513  ...  0.383802 -0.646584 -0.484200
# 73576 -0.057306  0.128246  0.080373  ...  0.383802 -1.539259 -0.484200
# 73579 -0.057306  0.128246 -0.189513  ...  0.383802 -1.539259  2.065262
# 73581 -0.057306  0.128246  0.080373  ...  0.383802 -0.646584 -0.484200
# 73584 -0.057306  0.128246  0.080373  ... -2.605509  0.246091  2.065262
#
#          SMQ860  SMQ870    SMQ872    SMQ874    SMQ878  SMAQUEX.x  HSD010
# SEQN
# 73568  1.125008     0.0 -2.081666  1.087115  1.463404   0.612440       1
# 73576  1.125008     0.0 -2.081666  1.087115 -0.683338  -1.632812       1
# 73579 -0.888883     0.0  0.480384 -0.919866 -0.683338  -1.632812       2
# 73581  1.125008     0.0  0.480384 -0.919866 -0.683338   0.612440       2
# 73584  1.125008     0.0  0.480384 -0.919866  1.463404  -1.632812       3
#
# [5 rows x 242 columns]

# %% [markdown]
# ## Plots

# %% [markdown]
# Let's take a look at the data. Below we visualize boxplots of family income to federal poverty line ratio ('INDFMPIR') and self-reported health condition. Notice how there are some clear patterns (the lower the ratio, the lower reported health condition), but it's not a perfect separation. We have 240+ features in our dataset, and we likely have several features in our dataset that highly correlate with our family income-poverty line ratio measure - PCA will help us simplify these.

# %%
current_palette = sns.color_palette("tab10", 5)
sns.set_palette(current_palette)

# %%
# Create a binary version of hsd010 where 1-3 are "good" and 4-5 are "poor"
nhanes_scaled['HSD010_binary'] = hsd010_binary = nhanes_scaled['HSD010'].replace(
    [1, 2, 3, 4, 5], ['good', 'good', 'good', 'poor', 'poor']) 
# Recode the original hsd010 with the string labels
nhanes_scaled['HSD010'] = nhanes_scaled['HSD010'].replace(
    [1, 2, 3, 4, 5], ['excellent', 'very good', 'good', 'fair', 'poor'])
# Boxplot of hsd010
ax = sns.boxplot(x = 'HSD010', y = 'INDFMPIR', data = nhanes_scaled,
                hue = 'HSD010', palette = "tab10")
ax.set(xlabel = "Self Reported Health Condition",
      ylabel = "Family Income to Poverty Line Ratio")
ax.set_title("Boxplot of Family Income to Poverty Line Ratio by Self-Reported Health Status")
plt.show()

# %%
# Boxplot of hsd010_binary
ax = sns.boxplot(x = 'HSD010_binary', y = 'INDFMPIR', data = nhanes_scaled, hue = 'HSD010_binary', palette = "tab10")
ax.set(xlabel = "Self Reported Health Condition",
      ylabel = "Family Income to Poverty Line Ratio")
ax.set_title("Boxplot of Family Income to Poverty Line Ratio by Binary Self-Reported Health Status")
plt.show()

# %% [markdown]
# Family income also is not necessarily well correlated with measured health outcomes. See below where we look at the relationship between Body Mass Index (BMI) and the family income-poverty line ratio, and shade points by self-reported health condition. It's hard to find a clear pattern - this is where clustering may come in handy.

# %%
ax = sns.scatterplot(x = "INDFMPIR", y = "BMXBMI", hue = "HSD010", palette = "tab10", data = nhanes_scaled)
ax.set(xlabel = "Income to Poverty Line Ratio",
      ylabel = "Body Mass Index")
ax.set_title("BMI v. Income-Poverty Ratio")
plt.show()

# %% [markdown]
# Before we move to working on unsupervised methods, we'll drop our target variables again:

# %%
nhanes_scaled_Binary = nhanes_scaled
nhanes_scaled = nhanes_scaled.drop(['HSD010', 'HSD010_binary'], axis = 1)

# %% [markdown]
# ## Principal Component Analysis

# %% [markdown]
# Conduct a Principal Component Analysis (PCA) of the nhanes data. The data has already been prepared for you, so you can work directly on nhanes_scaled. Be sure to do the following:
#
# - Choose the number of components and provide 1-2 sentences about your choice of the number of components.
# - Plot a barplot of the variation explained by each component. *Hint*: look at the attributes associated with your model.
# - Choose how many components you will use to fit a supervised learning model and provide 1-2 sentences to explain that choice.
# - Plot a 2D scatterplot of the first two components and provide 1-2 sentences analyzing the plot.

# %% [markdown]
# ### Train PCA and Discuss Number of Components

# %%
# Create a Scree plot to evaluate the number of components to keep
# --------------------------------------------------

# fit PCA
# ----------
pca_all = PCA() # notice we do not specify the number of components if we want to keep them all
principalComponents_breast = pca_all.fit_transform(nhanes_scaled)


# create scree plot from PCA fit
# ----------
PC_values = np.arange(pca_all.n_components_) + 1
plt.plot(PC_values, pca_all.explained_variance_ratio_, 'o-', linewidth=2, color='blue')
plt.title('Scree Plot')
plt.xlabel('Principal Component')
plt.ylabel('Variance Explained')
plt.show()

# %%
# cumulative percent of variance explained
# ----------
cumulative_variance = np.cumsum(pca_all.explained_variance_ratio_)

plt.figure(figsize=(6, 4))
plt.plot(PC_values, cumulative_variance, 'o-', linewidth=2, color='blue')
plt.axhline(y=0.9, color='red', linestyle='--', label='90% Variance')
plt.title('Cumulative Explained Variance')
plt.xlabel('Principal Component')
plt.ylabel('Cumulative Variance Explained')
plt.legend()
plt.show()

components_for_90_variance = np.argmax(cumulative_variance >= 0.9) + 1
print(f"Components for 90% Variance: {components_for_90_variance}")
# Out:
# Components for 90% Variance: 120

# %% [markdown]
# **Choice of the Number of Components: For Clustering (50 Components)**
#
# From the scree plot, the elbow point appears to be around 50 components. These 50 components capture the key structural features of the data while significantly reducing its dimensionality. This balance ensures that the overall data distribution is preserved, facilitating effective clustering without unnecessary complexity.

# %% [markdown]
# ### Barplot of Components

# %%
# Barplot of explained variance
# ----------
plt.figure(figsize=(10, 6))
plt.bar(range(1, len(pca_all.explained_variance_ratio_) + 1), 
        pca_all.explained_variance_ratio_, 
        alpha=0.7, color='blue', 
        label='Explained Variance')
plt.title('Variance Explained by Each Principal Component')
plt.xlabel('Principal Component')
plt.ylabel('Variance Explained')
plt.xticks(range(1, len(pca_all.explained_variance_ratio_) + 1, 10))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()
plt.show()

# %% [markdown]
# ### How many components will you use to fit a supervised learning model?

# %% [markdown]
# **Choice of the Number of Components: For Neural Network (120 Components)**
#
# As shown in *Cumulative Explained Variance Plot*, 120 components are needed to capture 90% variance, which preserves enough information to ensure accurate predictions in the neural network model. This choice simplifies the workflow while maintaining task performance.

# %% [markdown]
# ### 2D Scatterplot of the first two components

# %%
# plot
# ----------
X_2d = pca_all.transform(nhanes_scaled)[:, :2]

# figure settings
plt.figure()
plt.figure(figsize=(6,6))
plt.xticks(fontsize=8)
plt.yticks(fontsize=7)
plt.xlabel('Principal Component - 1',fontsize=10)
plt.ylabel('Principal Component - 2',fontsize=10)
plt.title("Principal Component Analysis of Breast Cancer Dataset",fontsize=13)
targets = ['good', 'poor']
colors = ['g', 'r']

# loop over targets and colors to create scatterplot
for target, color in zip(targets,colors):
    indicesToKeep = nhanes_scaled_Binary['HSD010_binary'] == target
    plt.scatter(X_2d[indicesToKeep, 0], X_2d[indicesToKeep, 1], c=color, s=40, alpha=.6, label=target)

# show figure
plt.legend(targets,prop={'size': 15})
plt.show()

# %% [markdown]
# **Interpretation**
# While the good category (green) shows more concentrated distribution, the poor category (red) is more dispersed. The overlap between the two categories indicates that the first two components alone may not fully distinguish between health states. Some outliers are observed. Additional components or nonlinear analysis may improve separability.

# %% [markdown]
# ## K-Means

# %% [markdown]
# - Choose a clustering algorithm and explain it in 1-2 sentences.
# - Cluster the nhanes data. Detail any choice you need to make with regards to number of clusters, and how you arrived at that choice. For instance, you might use the [elbow method](https://en.wikipedia.org/wiki/Elbow_method_(clustering)) if you choose k-means.
# - Plot your clusters on top of BMI v. Income Poverty Ratio Plot. Describe what you see in 1-2 sentences.
# - Retrain the clustering algorithm, but this time use your PCA results instead of the original dataframe. Plot the clusters on top of the 2D PCA scatterplot from the previous step. Describe your results in 1-2 sentences.

# %% [markdown]
# ### Choose a Clustering Algorithm

# %% [markdown]
# This is truly a tough decision.

# %% [markdown]
# Initially, I considered DBSCAN due to its ability to handle overlapping clusters and detect outliers, considering the overlap in the scatterplot above. However, my experiments showed that DBSCAN resulted in excessive noise points and poorly distributed clusters, especially when applied to the original data-most of the points falling into a single class (cluster 0) and very few points in other clusters (shown in plot *DBSCAN on Original Label: BMI v. Income-Poverty Ratio*).
#
# My interpretation for this is that DBSCAN is sensitive to the curse of dimensionality. If the data has many features, the Euclidean distance metric becomes less informative, making it hard to detect clusters. So I later implement DBSCAN on PCA result-50 components-and compare it with k-means clustering.
#
# In contrast, K-means provided a more balanced and interpretable outcome. It divided the data into three clusters (0, 1, 2) based on BMI and income-to-poverty ratio. Although the cluster boundaries were somewhat blurred, the cluster sizes and distributions were uniform, offering meaningful groupings for downstream tasks. Furthermore, K-means assigned all data points to clusters, avoiding the high noise levels seen with DBSCAN, which makes it more suitable for tasks like supervised learning.

# %%
# load library
# ----------
from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt
neighbors = NearestNeighbors(n_neighbors=5)
neighbors_fit = neighbors.fit(nhanes_scaled)
distances, indices = neighbors_fit.kneighbors(nhanes_scaled)
distances = np.sort(distances[:, 4], axis=0)
plt.plot(distances)
plt.ylabel("4th Nearest Neighbor Distance")
plt.xlabel("Data Points (sorted by distance)")
plt.show()

# %%
# define model object
# ----------
dbscan = DBSCAN(eps=10, min_samples=4)

# fit model to data 
# ----------
dbscan.fit(nhanes_scaled)
# Out:
# DBSCAN(eps=10, min_samples=4)

# %%
# get fitted labels for each data point 
labels_db = dbscan.labels_
print(np.unique(labels, return_counts=True))
# Out:
# (array([0, 1, 2], dtype=int32), array([ 567, 1330,  167]))

# %%
# define model object on PCA components
# ----------
pca_transformed_50 = pca_all.transform(nhanes_scaled)[:, :50] 
dbscan_PCA = DBSCAN(eps=9, min_samples=4).fit(pca_transformed_50)

# %%
# get fitted labels for each data point 
labels_dbscan = dbscan_PCA.labels_
print(np.unique(labels_dbscan, return_counts=True))
# Out:
# (array([-1,  0,  1,  2]), array([ 776, 1269,   12,    7]))

# %% [markdown]
# ### Cluster nhanes

# %%
# Calculate SSE for different numbers of clusters
sse = []
for k in range(1, 11):  # Test k from 1 to 10
    kmeans = KMeans(n_clusters=k, n_init=10, max_iter=300, random_state=42)
    kmeans.fit(nhanes_scaled)
    sse.append(kmeans.inertia_)

# Plot the elbow curve
plt.figure(figsize=(6, 4))
plt.plot(range(1, 11), sse, marker='o')
plt.xlabel('Number of Clusters (k)', fontsize=12)
plt.ylabel('Sum of Squared Errors (SSE)', fontsize=12)
plt.title('Elbow Method for Optimal k', fontsize=14)
plt.grid()
plt.show()

# %% [markdown]
# Based on the elbow plot, the elbow point is observed at k=3, after k=3, the rate of decrease in SSE starts to slow down, and the curve becomes more gradual. Selecting k=3 is a reasonable choice as it captures the majority of variance in the data while keeping the number of clusters manageable.

# %%
# specify kmeans algorithm 
# ----------
kmeans = KMeans(n_clusters=3,
                n_init=10,
                max_iter=300 #default
                ).fit(nhanes_scaled)

# %%
labels_k = kmeans.labels_

# %% [markdown]
# ### Plot your clusters on top of the BMI v. Income Poverty Ratio Plot

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 8), sharey=True)

sns.scatterplot(ax=axes[0, 0], x="INDFMPIR", y="BMXBMI", hue=labels_k, palette="tab10", data=nhanes_scaled)
axes[0, 0].set_title('K-means on Original Data: BMI v. Income-Poverty Ratio')
axes[0, 0].set(xlabel="Income to Poverty Line Ratio", ylabel="Body Mass Index")

sns.scatterplot(ax=axes[0, 1], x="INDFMPIR", y="BMXBMI", hue=labels_dbscan, palette="tab10", data=nhanes_scaled_Binary)
axes[0, 1].set_title('DBSCAN on Original Label: BMI v. Income-Poverty Ratio')
axes[0, 1].set(xlabel="Income to Poverty Line Ratio", ylabel="Body Mass Index")

sns.scatterplot(ax=axes[1, 0], x="INDFMPIR", y="BMXBMI", hue="HSD010_binary", palette="tab10", data=nhanes_scaled_Binary)
axes[1, 0].set_title('Original Binary Label: BMI v. Income-Poverty Ratio')
axes[1, 0].set(xlabel="Income to Poverty Line Ratio", ylabel="Body Mass Index")


sns.scatterplot(ax=axes[1, 1], x="INDFMPIR", y="BMXBMI", hue="HSD010", palette="tab10", data=nhanes_scaled_Binary)
axes[1, 1].set_title('Original Label: BMI v. Income-Poverty Ratio')
axes[1, 1].set(xlabel="Income to Poverty Line Ratio", ylabel="Body Mass Index")

axes[0, 0].legend(title="Cluster", loc='best')
axes[1, 0].legend(title="HSD010", loc='best')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation on K-means clustering result**
# - Cluster Distribution: The three clusters (0, 1, 2) show distinct patterns. Cluster 0 (blue) is concentrated in low BMI and low Income-to-Poverty Ratio regions, Cluster 2 (green) spans a wider horizontal range, and Cluster 1 (orange) overlaps significantly with the others, particularly in areas with moderate BMI and income ratios.
# - Cluster Overlap: Cluster 1 overlaps with Cluster 2 in higher BMI regions (2-3) and with Cluster 0 in low BMI and income areas.
# - Sparse Data: Data is sparse in higher income ratio regions (>0.5), where Clusters 0 and 2 are less represented, but Cluster 1 still has some presence.
#
# **Comparison with DBSCAN**: K-means divides the data into three clusters (0, 1, 2) based on BMI and income. While the cluster boundaries are somewhat blurred, the clusters are more balanced and evenly distributed, providing a reasonable grouping of the data. Compared to DBSCAN’s high number of noise points, K-means assigns all data points to clusters, which is advantageous for certain downstream tasks such as supervised learning.
#
# **Comparison with original label**: The original HSD010 labels show similar patterns, with “poor” aligning with Cluster 0 and “good/very good” resembling Cluster 1. However, Cluster 2’s broader horizontal distribution is less apparent in HSD010.

# %% [markdown]
# ### Retrain the clustering algorithm on PCA components and plot clusters on your 2D scatter

# %%
# retrain the clustering using 50 components
# ----------
kmeans_pca50 = KMeans(n_clusters=3,
                    n_init=10,
                    max_iter=300
                   ).fit(pca_transformed_50)

# plot clusters on your 2D scatter
# ----------
labels_pca50 = kmeans_pca50.labels_
cluster_centers_pca50 = kmeans_pca.cluster_centers_

fig, axes = plt.subplots(1, 2, figsize=(20, 8), sharex=True, sharey=True)

axes[0].scatter(pca_transformed_50[:, 0], pca_transformed_50[:, 1], c=labels_pca50, cmap='viridis', s=50, alpha=0.7)
axes[0].scatter(cluster_centers_pca50[:, 0], cluster_centers_pca50[:, 1], c='red', marker='+', s=200, label='Cluster Centers')

axes[0].set_title('K-means on PCA Data (50 Components)', fontsize=16)
axes[0].set_xlabel('Principal Component 1', fontsize=14)
axes[0].set_ylabel('Principal Component 2', fontsize=14)

axes[1].scatter(pca_transformed_50[:, 0], pca_transformed_50[:, 1], c=labels_dbscan, cmap='viridis', s=50, alpha=0.7)

axes[1].set_title('DBSCAN on PCA Data (50 Components)', fontsize=16)
axes[1].set_xlabel('Principal Component 1', fontsize=14)
axes[1].set_ylabel('Principal Component 2', fontsize=14)

plt.show()

# %% [markdown]
# ## Neural Network

# %% [markdown]
# Now we are ready to predict! Do the following:
#
# - Choose either HSD010 or HSD010\_binary as your target outcome.
# - Train a neural network using the original features. Much of the code to train a basic neural net has been set up for you, but you will need to fill in a couple of missing pieces.
# - Train a neural network using only your PCA components as features.
# - Train a neural network using your PCA components and the predicted class membership from your clustering algorithm as features.
# - Compare and contrast how well each algorithm did. Which featurization technique would you pick and why?

# %% [markdown]
# Below we provide a template for training a neural network. Use this template for training on the original features, on the PCA components, and the PCA components + the predicted classes from your clusters.

# %% [markdown]
# ### Neural Network on Original Features

# %% [markdown]
# I choose ***hsd010_binary*** as the target outcome because the subjective nature of self-reported health assessments makes the distinctions between categories like “fair,” “good,” and “very good” subtle and potentially inconsistent. By reducing the target to a binary outcome, we focus on a more meaningful and robust differentiation, which is better suited for training a neural network.

# %%
# partition data
# -----------
y = nhanes_scaled_Binary['HSD010_binary'].replace(['good', 'poor'], [0, 1]) # either hsd010 or hsd010_binary, may need to convert to numeric if it isn't already 
X = nhanes_scaled # drop out any columns that aren't features

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size = .25, 
                                                    random_state = 10)
# Out:
# /var/folders/gz/txr1ywf13ss49jh8_z6ygy4h0000gn/T/ipykernel_55625/293913527.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   y = nhanes_scaled_Binary['HSD010_binary'].replace(['good', 'poor'], [0, 1]) # either hsd010 or hsd010_binary, may need to convert to numeric if it isn't already

# %%
# load libraries
# -----------
import keras
from keras.utils import to_categorical

num_classes = len(np.unique(y))
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes=num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes=num_classes)
num_classes = y_test.shape[1]

# %%
# create neural network model
# -----------
model = Sequential()

model.add(Dense(64, input_dim=X_train.shape[1], kernel_initializer='he_uniform', activation='relu'))

model.add(Dense(32, kernel_initializer='he_uniform', activation='relu'))

## Add any additional layers you wish here

model.add(Dense(2, kernel_initializer='he_uniform', activation='softmax'))  # output layer

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=32, verbose=1)
# Out:
# /opt/anaconda3/envs/CSS/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7069 - loss: 0.5958 - val_accuracy: 0.8372 - val_loss: 0.4122
# Epoch 2/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8575 - loss: 0.3419 - val_accuracy: 0.8411 - val_loss: 0.3868
# Epoch 3/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9232 - loss: 0.2225 - val_accuracy: 0.8469 - val_loss: 0.3798
# Epoch 4/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9373 - loss: 0.1937 - val_accuracy: 0.8372 - val_loss: 0.3828
# Epoch 5/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9449 - loss: 0.1555 - val_accuracy: 0.8353 - val_loss: 0.3926
# Epoch 6/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9677 - loss: 0.1157 - val_accuracy: 0.8391 - val_loss: 0.4026
# Epoch 7/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9770 - loss: 0.0837 - val_accuracy: 0.8411 - val_loss: 0.4309
# Epoch 8/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9830 - loss: 0.0689 - val_accuracy: 0.8411 - val_loss: 0.4536
# Epoch 9/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9909 - loss: 0.0490 - val_accuracy: 0.8333 - val_loss: 0.4752
# Epoch 10/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9972 - loss: 0.0351 - val_accuracy: 0.8333 - val_loss: 0.5035
# Epoch 11/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9963 - loss: 0.0279 - val_accuracy: 0.8372 - val_loss: 0.5279
# Epoch 12/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9978 - loss: 0.0187 - val_accuracy: 0.8450 - val_loss: 0.5518
# Epoch 13/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0159 - val_accuracy: 0.8469 - val_loss: 0.5756
# Epoch 14/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0114 - val_accuracy: 0.8450 - val_loss: 0.6029
# Epoch 15/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0083 - val_accuracy: 0.8469 - val_loss: 0.6244
# Epoch 16/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.8488 - val_loss: 0.6423
# Epoch 17/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.8469 - val_loss: 0.6600
# Epoch 18/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.8469 - val_loss: 0.6807
# Epoch 19/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.8450 - val_loss: 0.6989
# Epoch 20/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.8430 - val_loss: 0.7148
# Epoch 21/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.8450 - val_loss: 0.7299
# Epoch 22/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.8469 - val_loss: 0.7433
# Epoch 23/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.8508 - val_loss: 0.7557
# Epoch 24/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.8527 - val_loss: 0.7688
# Epoch 25/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.8488 - val_loss: 0.7794
# Epoch 26/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.8508 - val_loss: 0.7934
# Epoch 27/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.8488 - val_loss: 0.8028
# Epoch 28/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.8508 - val_loss: 0.8121
# Epoch 29/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8527 - val_loss: 0.8229
# Epoch 30/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8508 - val_loss: 0.8345
# Epoch 31/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.8508 - val_loss: 0.8439
# Epoch 32/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 8.3058e-04 - val_accuracy: 0.8527 - val_loss: 0.8516
# Epoch 33/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 7.9098e-04 - val_accuracy: 0.8527 - val_loss: 0.8623
# Epoch 34/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 7.9573e-04 - val_accuracy: 0.8527 - val_loss: 0.8698
# Epoch 35/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 1.0000 - loss: 6.6342e-04 - val_accuracy: 0.8527 - val_loss: 0.8791
# Epoch 36/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 6.3252e-04 - val_accuracy: 0.8527 - val_loss: 0.8887
# Epoch 37/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 5.5525e-04 - val_accuracy: 0.8527 - val_loss: 0.8956
# Epoch 38/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 5.2746e-04 - val_accuracy: 0.8527 - val_loss: 0.9029
# Epoch 39/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 5.2389e-04 - val_accuracy: 0.8527 - val_loss: 0.9117
# Epoch 40/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 4.5034e-04 - val_accuracy: 0.8527 - val_loss: 0.9182
# Epoch 41/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 4.4759e-04 - val_accuracy: 0.8527 - val_loss: 0.9269
# Epoch 42/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 3.7886e-04 - val_accuracy: 0.8527 - val_loss: 0.9329
# Epoch 43/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 3.7394e-04 - val_accuracy: 0.8527 - val_loss: 0.9411
# Epoch 44/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 3.2454e-04 - val_accuracy: 0.8527 - val_loss: 0.9482
# Epoch 45/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 3.0729e-04 - val_accuracy: 0.8527 - val_loss: 0.9544
# Epoch 46/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 3.4052e-04 - val_accuracy: 0.8527 - val_loss: 0.9615
# Epoch 47/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 2.5187e-04 - val_accuracy: 0.8527 - val_loss: 0.9676
# Epoch 48/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 2.6337e-04 - val_accuracy: 0.8527 - val_loss: 0.9746
# Epoch 49/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 2.6122e-04 - val_accuracy: 0.8527 - val_loss: 0.9820
# Epoch 50/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 2.2379e-04 - val_accuracy: 0.8547 - val_loss: 0.9870

# %% [markdown]
# ### Neural Network on Principal Components

# %%
pca_transformed120 = pca_all.transform(nhanes_scaled)[:, :120]  # top 120 components

X_train_pca, X_test_pca, y_train_pca, y_test_pca = train_test_split(pca_transformed120, 
                                                    y, 
                                                    test_size = .25, 
                                                    random_state = 10)
y_train_pca = keras.utils.to_categorical(y_train_pca, num_classes=num_classes)
y_test_pca = keras.utils.to_categorical(y_test_pca, num_classes=num_classes)

model_pca = Sequential()

model_pca.add(Dense(64, input_dim=X_train_pca.shape[1], kernel_initializer='he_uniform', activation='relu'))
model_pca.add(Dense(32, kernel_initializer='he_uniform', activation='relu'))
model_pca.add(Dense(2, kernel_initializer='he_uniform', activation='softmax'))

model_pca.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model_pca.fit(X_train_pca, y_train_pca, validation_data=(X_test_pca, y_test_pca), epochs=50, batch_size=32, verbose=1)
# Out:
# /opt/anaconda3/envs/CSS/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8336 - loss: 0.4912 - val_accuracy: 0.8411 - val_loss: 0.4380
# Epoch 2/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8805 - loss: 0.3180 - val_accuracy: 0.8488 - val_loss: 0.4106
# Epoch 3/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9087 - loss: 0.2597 - val_accuracy: 0.8547 - val_loss: 0.3987
# Epoch 4/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9101 - loss: 0.2509 - val_accuracy: 0.8527 - val_loss: 0.4038
# Epoch 5/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9222 - loss: 0.2053 - val_accuracy: 0.8469 - val_loss: 0.4045
# Epoch 6/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9464 - loss: 0.1559 - val_accuracy: 0.8508 - val_loss: 0.4130
# Epoch 7/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9499 - loss: 0.1379 - val_accuracy: 0.8469 - val_loss: 0.4255
# Epoch 8/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9707 - loss: 0.1082 - val_accuracy: 0.8450 - val_loss: 0.4448
# Epoch 9/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9672 - loss: 0.0990 - val_accuracy: 0.8450 - val_loss: 0.4606
# Epoch 10/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9831 - loss: 0.0783 - val_accuracy: 0.8391 - val_loss: 0.4816
# Epoch 11/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9888 - loss: 0.0697 - val_accuracy: 0.8430 - val_loss: 0.5095
# Epoch 12/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9910 - loss: 0.0569 - val_accuracy: 0.8450 - val_loss: 0.5343
# Epoch 13/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9938 - loss: 0.0419 - val_accuracy: 0.8314 - val_loss: 0.5574
# Epoch 14/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9962 - loss: 0.0371 - val_accuracy: 0.8411 - val_loss: 0.5923
# Epoch 15/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9964 - loss: 0.0286 - val_accuracy: 0.8391 - val_loss: 0.6184
# Epoch 16/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9981 - loss: 0.0238 - val_accuracy: 0.8430 - val_loss: 0.6461
# Epoch 17/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9967 - loss: 0.0206 - val_accuracy: 0.8314 - val_loss: 0.6654
# Epoch 18/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - accuracy: 0.9995 - loss: 0.0150 - val_accuracy: 0.8295 - val_loss: 0.6871
# Epoch 19/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9994 - loss: 0.0132 - val_accuracy: 0.8333 - val_loss: 0.7149
# Epoch 20/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9996 - loss: 0.0112 - val_accuracy: 0.8411 - val_loss: 0.7430
# Epoch 21/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9997 - loss: 0.0095 - val_accuracy: 0.8314 - val_loss: 0.7621
# Epoch 22/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 0.8333 - val_loss: 0.7795
# Epoch 23/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 0.8391 - val_loss: 0.7995
# Epoch 24/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.8333 - val_loss: 0.8167
# Epoch 25/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.8391 - val_loss: 0.8349
# Epoch 26/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.8391 - val_loss: 0.8515
# Epoch 27/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 974us/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.8353 - val_loss: 0.8674
# Epoch 28/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.8314 - val_loss: 0.8772
# Epoch 29/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.8353 - val_loss: 0.8943
# Epoch 30/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.8372 - val_loss: 0.9080
# Epoch 31/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.8372 - val_loss: 0.9204
# Epoch 32/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.8430 - val_loss: 0.9337
# Epoch 33/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.8411 - val_loss: 0.9461
# Epoch 34/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.8411 - val_loss: 0.9563
# Epoch 35/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.8430 - val_loss: 0.9695
# Epoch 36/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.8450 - val_loss: 0.9800
# Epoch 37/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.8430 - val_loss: 0.9896
# Epoch 38/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.8450 - val_loss: 0.9998
# Epoch 39/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.8450 - val_loss: 1.0105
# Epoch 40/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.8450 - val_loss: 1.0212
# Epoch 41/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.8450 - val_loss: 1.0308
# Epoch 42/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.8450 - val_loss: 1.0387
# Epoch 43/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 9.5267e-04 - val_accuracy: 0.8450 - val_loss: 1.0483
# Epoch 44/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 1.0000 - loss: 9.2501e-04 - val_accuracy: 0.8450 - val_loss: 1.0571
# Epoch 45/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 8.2889e-04 - val_accuracy: 0.8450 - val_loss: 1.0648
# Epoch 46/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 8.5671e-04 - val_accuracy: 0.8450 - val_loss: 1.0740
# Epoch 47/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 7.6967e-04 - val_accuracy: 0.8450 - val_loss: 1.0817
# Epoch 48/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step - accuracy: 1.0000 - loss: 7.2995e-04 - val_accuracy: 0.8450 - val_loss: 1.0911
# Epoch 49/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - accuracy: 1.0000 - loss: 6.8707e-04 - val_accuracy: 0.8450 - val_loss: 1.0990
# Epoch 50/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 5.8113e-04 - val_accuracy: 0.8450 - val_loss: 1.1086

# %% [markdown]
# ### Neural Network on Principal Components + Cluster Membership

# %%
combined_features = np.hstack((pca_transformed120, labels_k.reshape(-1, 1)))
X_train_comb, X_test_comb, y_train_comb, y_test_comb = train_test_split(combined_features,
                                                                        y,
                                                                        test_size=0.25,
                                                                        random_state=10)
y_train_comb = to_categorical(y_train_comb, num_classes=2)
y_test_comb = to_categorical(y_test_comb, num_classes=2)

model_comb = Sequential()

model_comb.add(Dense(64, input_dim=X_train_comb.shape[1], kernel_initializer='he_uniform', activation='relu'))
model_comb.add(Dense(32, kernel_initializer='he_uniform', activation='relu'))
model_comb.add(Dense(2, kernel_initializer='he_uniform', activation='softmax'))

model_comb.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model_comb.fit(X_train_comb, y_train_comb, validation_data=(X_test_comb, y_test_comb), epochs=50, batch_size=32, verbose=1)
# Out:
# Epoch 1/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6543 - loss: 0.8032 - val_accuracy: 0.8120 - val_loss: 0.4862
# Epoch 2/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8500 - loss: 0.3655 - val_accuracy: 0.8372 - val_loss: 0.4194
# Epoch 3/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8987 - loss: 0.2752 - val_accuracy: 0.8430 - val_loss: 0.4069
# Epoch 4/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9178 - loss: 0.2172 - val_accuracy: 0.8508 - val_loss: 0.4009
# Epoch 5/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9350 - loss: 0.1846 - val_accuracy: 0.8411 - val_loss: 0.4043
# Epoch 6/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9380 - loss: 0.1733 - val_accuracy: 0.8469 - val_loss: 0.4115
# Epoch 7/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9291 - loss: 0.1681 - val_accuracy: 0.8488 - val_loss: 0.4206
# Epoch 8/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9619 - loss: 0.1162 - val_accuracy: 0.8430 - val_loss: 0.4267
# Epoch 9/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9640 - loss: 0.1174 - val_accuracy: 0.8450 - val_loss: 0.4416
# Epoch 10/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9731 - loss: 0.0946 - val_accuracy: 0.8547 - val_loss: 0.4574
# Epoch 11/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9859 - loss: 0.0732 - val_accuracy: 0.8585 - val_loss: 0.4732
# Epoch 12/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9798 - loss: 0.0744 - val_accuracy: 0.8566 - val_loss: 0.4963
# Epoch 13/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9929 - loss: 0.0460 - val_accuracy: 0.8527 - val_loss: 0.5128
# Epoch 14/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9944 - loss: 0.0477 - val_accuracy: 0.8527 - val_loss: 0.5386
# Epoch 15/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9975 - loss: 0.0369 - val_accuracy: 0.8527 - val_loss: 0.5579
# Epoch 16/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9985 - loss: 0.0290 - val_accuracy: 0.8508 - val_loss: 0.5897
# Epoch 17/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9984 - loss: 0.0234 - val_accuracy: 0.8469 - val_loss: 0.6133
# Epoch 18/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0179 - val_accuracy: 0.8469 - val_loss: 0.6344
# Epoch 19/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0141 - val_accuracy: 0.8450 - val_loss: 0.6589
# Epoch 20/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0133 - val_accuracy: 0.8508 - val_loss: 0.6805
# Epoch 21/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0100 - val_accuracy: 0.8508 - val_loss: 0.6998
# Epoch 22/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 0.8430 - val_loss: 0.7186
# Epoch 23/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0071 - val_accuracy: 0.8430 - val_loss: 0.7378
# Epoch 24/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.8450 - val_loss: 0.7570
# Epoch 25/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.8450 - val_loss: 0.7744
# Epoch 26/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.8430 - val_loss: 0.7921
# Epoch 27/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.8469 - val_loss: 0.8081
# Epoch 28/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.8430 - val_loss: 0.8257
# Epoch 29/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.8469 - val_loss: 0.8397
# Epoch 30/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.8450 - val_loss: 0.8524
# Epoch 31/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.8469 - val_loss: 0.8683
# Epoch 32/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.8450 - val_loss: 0.8805
# Epoch 33/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.8450 - val_loss: 0.8943
# Epoch 34/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.8450 - val_loss: 0.9069
# Epoch 35/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.8450 - val_loss: 0.9207
# Epoch 36/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.8450 - val_loss: 0.9318
# Epoch 37/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.8450 - val_loss: 0.9446
# Epoch 38/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.8450 - val_loss: 0.9555
# Epoch 39/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.8450 - val_loss: 0.9676
# Epoch 40/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.8411 - val_loss: 0.9761
# Epoch 41/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.8411 - val_loss: 0.9891
# Epoch 42/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 9.9203e-04 - val_accuracy: 0.8391 - val_loss: 0.9976
# Epoch 43/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.8411 - val_loss: 1.0088
# Epoch 44/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 9.4201e-04 - val_accuracy: 0.8372 - val_loss: 1.0183
# Epoch 45/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 9.1540e-04 - val_accuracy: 0.8353 - val_loss: 1.0284
# Epoch 46/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 8.8079e-04 - val_accuracy: 0.8353 - val_loss: 1.0382
# Epoch 47/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 7.2178e-04 - val_accuracy: 0.8353 - val_loss: 1.0459
# Epoch 48/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 7.0009e-04 - val_accuracy: 0.8353 - val_loss: 1.0551
# Epoch 49/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 6.5954e-04 - val_accuracy: 0.8353 - val_loss: 1.0643
# Epoch 50/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 6.3410e-04 - val_accuracy: 0.8353 - val_loss: 1.0726

# %%
# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
loss_pca, accuracy_pca = model_pca.evaluate(X_test_pca, y_test_pca, verbose=0)
loss_comb, accuracy_comb = model_comb.evaluate(X_test_comb, y_test_comb, verbose=0)

print(f"Test Accuracy on Original Features: {accuracy:.2f}")
print(f"Test Accuracy on PCA Features: {accuracy_pca:.2f}")
print(f"Test Accuracy on PCA + Cluster Features: {accuracy_comb:.2f}")
# Out:
# Test Accuracy on Original Features: 0.85
# Test Accuracy on PCA Features: 0.84
# Test Accuracy on PCA + Cluster Features: 0.84

# %% [markdown]
# **Interpretation of Results**
#
# The results indicates that reducing the dimensionality or adding clustering features did not provide any notable improvements in predictive performance.
# - Original Features: Retaining all the original features likely preserved the full variance and complexity of the dataset, enabling the neural network to learn richer patterns.
# - PCA Features: While PCA successfully reduced the dimensionality to 120 components, it might have discarded some critical information that the network could use to improve predictions, resulting in a slight performance drop.
# - PCA + Clustering Features: Adding cluster labels to the PCA-transformed features introduced no observable benefits, likely because the clustering results did not align well with the target variable (HSD010_binary). The clustering process may have introduced noise or redundant information.
#
# **Reflection**
#
# After seeing these results, I felt emptiness… I mean, with all the efforts and detailed steps taken in this project, the results turned out to be a confirmation of futility, which is undoubtedly frustrating.
#
# However, I do appreciate the workflow and design of this project. Even though the results didn’t yield significant improvements, the process itself offered a valuable opportunity to explore different methodologies, understand their implementation, and critically evaluate their impacts. To be honest, at first, I found this project “less organized and straightforward” compared to previous ones. There were moments where the direction felt unclear, and it required extra effort to piece everything together.
#
# That said, completing all the steps has certainly deepened my understanding of unsupervised learning techniques like PCA and clustering, as well as their interplay with supervised learning tasks. My intuition for analyzing and preparing complex datasets has improved significantly, and I feel more confident in tackling similar challenges in the future.

# %% [markdown]
# ## Discussion Questions

# %% [markdown]
# **1. In your own words, what is the difference between PCA and clustering?**

# %% [markdown]
# PCA and clustering served different purposes in this project. PCA was used to reduce the dimensionality of the original features, transforming them into a set of principal components that captured most of the variance in the data. In other words, PCA is used to abandon having redundant features, simplifying the data structure while preserving as much information as possible. For example, we retained 120 principal components, which represented a large proportion of the original variance.
#
# In contrast, clustering (e.g., K-means and DBSCAN) aimed to group data points into clusters based on their similarities, independent of the target variable. For instance, in our analysis, K-means grouped the data into three clusters, while DBSCAN identified a significant number of noise points, reflecting the differences in their approaches. PCA focused on simplifying the feature space, while clustering attempted to uncover inherent group structures in the data.

# %% [markdown]
# **2. Did you notice any advantages to combining PCA and clustering? If so, what do you think they were? If not, why do you think you didn't see any gains from this combination?**

# %% [markdown]
# Initially, I assumed that combining PCA and clustering would yield positive results by reducing redundant features and lowering the risk of overfitting, thus simplifying the input space for the neural network. This combination was expected to serve as an effective pre-processing step, especially for handling correlated features.
#
# However, in practice, combining PCA and clustering did not lead to significant improvements in this project. The test accuracy for the model using PCA + cluster features (0.84) was slightly lower than using only the original features (0.85). This suggests that the clustering results did not provide additional value in predicting the target variable (HSD010_binary).
#
# My guess for this is that neural networks are inherently effective at performing dimensionality reduction in internal layers. As a result, adding PCA might have removed information that the neural network could have otherwise used. Thus we would not gain anything from combining PCA and clustering. Furthermore, the dataset itself contains a mix of correlated and uncorrelated features, and clustering may not have aligned well with the structure of the target variable. Nevertheless, though after applying PCA and clustering I didn't get appropriate result, it still make sense to definitely try to apply PCA to investigate it works or not, as the success of these methods highly depends on the specific dataset and problem.

# %% [markdown]
# **3. How can unsupervised techniques help with downstream supervised learning tasks when working with "big data?"**

# %% [markdown]
# Unsupervised techniques like PCA and clustering can significantly assist in handling “big data” by reducing the dimensionality of the data and uncovering hidden patterns. For instance, in this project, PCA reduced the dataset to 120 components, improving computational efficiency and potentially mitigating the curse of dimensionality. This dimensionality reduction also serves as a form of regularization, reducing the risk of overfitting when training neural networks.
#
# Moreover, clustering can reveal latent structures or groupings in the data, which may be used as additional features to enhance model performance. In practice, neural networks often rely on gradient-based optimization, which benefits from a well-conditioned input space. Transformations like PCA help center, scale, and simplify the data, improving convergence speed and the quality of results. While our project showed limited gains from clustering, it highlighted the potential of these techniques to improve data preprocessing and downstream learning when carefully aligned with the problem.
